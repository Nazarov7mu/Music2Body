# %%
# !python pytorch_A2B_dynamics.py --data "data/train_body.json" --logfldr 'data/log_1' --numpca -1 --batch_size 300
# Out:
# DEBUG:mannerisms_rnn:Training model
# INFO:mannerisms_rnn:Epoch 1 / 300
# INFO:mannerisms_rnn:Training Loss (1980 x 1080): (20.71364940480983, 8.049179417021731)
# INFO:mannerisms_rnn:Validation Loss (1980 x 1080): (16.938965710726652, 6.029089851812883)
# INFO:mannerisms_rnn:Epoch 2 / 300
# INFO:mannerisms_rnn:Training Loss (1980 x 1080): (19.54625967715649, 7.29526393464271)
# INFO:mannerisms_rnn:Validation Loss (1980 x 1080): (16.715663389726117, 5.471957434307445)
# INFO:mannerisms_rnn:Epoch 3 / 300
# INFO:mannerisms_rnn:Training Loss (1980 x 1080): (19.316948971849808, 7.205629460355069)
# INFO:mannerisms_rnn:Validation Loss (1980 x 1080): (16.858050953258168, 6.080322373997081)
# INFO:mannerisms_rnn:Epoch 4 / 300
# INFO:mannerisms_rnn:Training Loss (1980 x 1080): (18.285993799250175, 6.4831721681229615)
# INFO:mannerisms_rnn:Validation Loss (1980 x 1080): (17.21983710202304, 5.485694516788829)
# INFO:mannerisms_rnn:Epoch 5 / 300
# ...

# %%
# !python pytorch_A2B_dynamics.py --test_model data/log_1/best_model_db.pth --logfldr data/log_1 --data data/test_body.json --audio_file data/test_audio.wav --batch_size 1 --visualize True
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Traceback (most recent call last):
#   File "pytorch_A2B_dynamics.py", line 359, in <module>
#     main()
#   File "pytorch_A2B_dynamics.py", line 352, in main
#     visualizeKeypoints(args.vidtype, targ, pred, args.audio_file, vid_path)
#   File "/root/Audio2BodyDynamics-master/visualize.py", line 192, in visualizeKeypoints
#     color=pred_color)
#   File "/root/Audio2BodyDynamics-master/visualize.py", line 145, in drawBodyAndFingers
#     x1, x2 = int(x[indices[0]]), int(x[indices[1]])
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %%
# !python generate_stitched_video.py --vidtype piano --body_path data/log_1/piano_data.json
# Out:
# Traceback (most recent call last):
#   File "generate_stitched_video.py", line 81, in <module>
#     main()
#   File "generate_stitched_video.py", line 64, in main
#     righthand = json.load(open(args.righthand_path, 'r+'))
# FileNotFoundError: [Errno 2] No such file or directory: 'righthand_data.json'

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True
