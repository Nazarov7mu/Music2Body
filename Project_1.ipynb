# %%
# !python pytorch_A2B_dynamics.py --logfldr data/new_logs/log_original_without_fc --data data/train_poses_and_audio.json --numpca 15 --patience 300 --hidden_size 200
# Out:
# {'device': device(type='cuda', index=0), 'dropout': 0.1, 'batch_size': 100, 'hidden_dim': 200, 'input_dim': 10, 'output_dim': 15, 'trainable_init': True}
# DEBUG:mannerisms_rnn:Training model
# INFO:mannerisms_rnn:Epoch 1 / 300
# INFO:mannerisms_rnn:Training Loss (1980 x 1080): (19.586298094855415, 1.7179065798268174)
# INFO:mannerisms_rnn:Validation Loss (1980 x 1080): (19.575001678466798, 1.7741428709030151)
# INFO:mannerisms_rnn:Time to complete the epoch:--- 2.212629556655884 seconds ---
# INFO:mannerisms_rnn:Epoch 2 / 300
# INFO:mannerisms_rnn:Training Loss (1980 x 1080): (19.132612083897445, 1.6635732909645697)
# INFO:mannerisms_rnn:Validation Loss (1980 x 1080): (19.379355239868165, 1.7716344022750854)
# INFO:mannerisms_rnn:Time to complete the epoch:--- 5.621711254119873 seconds ---
# INFO:mannerisms_rnn:Epoch 3 / 300
# INFO:mannerisms_rnn:Training Loss (1980 x 1080): (19.015980123269436, 1.651219069355666)
# ...

# %%
# !python pytorch_A2B_dynamics.py --test_model data/new_logs/log_original_without_fc/Epoch_300/model_db.pth --logfldr data/new_logs/log_original_without_fc/ --audio_file data/audio/blank.wav --data data/audio/audiotest_blank.json --numpca 15 --visualize True --batch_size 1 --dp 0.1
# Out:
# {'device': device(type='cuda', index=0), 'dropout': 0.1, 'batch_size': 1, 'hidden_dim': 200, 'input_dim': 10, 'output_dim': 15, 'trainable_init': True}
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# --->
# data/new_logs/log_original_without_fc//piano_audio.mp4
# File 'data/new_logs/log_original_without_fc//piano_audio.mp4' already exists. Overwrite ? [y/N] INFO:mannerisms_rnn:The best validation is : [nan, 267.55853271484375]

# %%
import json
import numpy as np
data_loc = 'data/train_poses_and_audio.json'
with open(data_loc, "r+") as fhandle:
    data = json.load(fhandle)

# %%
d = np.array(data)

# %%
len(data['1'][0])
# Out:
# 4783

# %%
fr = 0
for i in range(48):
    fr += len(data[str(i)][0])

# %%
fr
# Out:
# 187554
